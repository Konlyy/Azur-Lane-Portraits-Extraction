# %% [markdown]
# ## Download images at https://azurlane.koumakan.jp/

# %% [markdown]
# ---
# ### 【0】首先导入必要的包，定义一些变量

# %%
import os
import re
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

UserAgent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
headers = {"User-Agent": UserAgent}

Ship_Image_URL = "https://azurlane.koumakan.jp/wiki/List_of_Ships_by_Image"
save_folder = "/kaggle/working/20250328"
os.makedirs(save_folder, exist_ok=True)

# %% [markdown]
# ---
# ### 【1】先写一个从Ship_Image_URL获取所有Ship的Gallery的绝对网址

# %%
def get_ship_links():
    
    main_url = "https://azurlane.koumakan.jp/wiki/List_of_Ships_by_Image"
    base_url = "https://azurlane.koumakan.jp"  # 用于拼接完整 URL
    gall_url = "/Gallery"

    try:
        response = requests.get(main_url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")

        i1 = 0
        i2 = 0
        i3 = 0
        ship_names = []
        ship_links = []
        
        # 找到所有 <div class="azl-shipcard">
        for ship_card in soup.find_all("div", class_="azl-shipcard"):
            i1 += 1
            # 在 ship_card 下找到 <div class="alc-top chuncate"> 里的 <a>
            alc_top = ship_card.find("div", class_="alc-top truncate")
            if alc_top:
                i2 += 1
                a_tag = alc_top.find("a")
                if a_tag and a_tag.get("href"):
                    i3 += 1
                    link = f"{base_url}{a_tag['href']}{gall_url}"
                    ship_links.append(link)
                    ship_names.append(a_tag.get_text(strip=True))

        print(f"共有{i1}个符合特征 <div class='azl-shipcard'>")
        print(f"共有{i2}个符合特征 <div class='azl-shipcard'> && <a>")
        print(f"共有{i3}个符合特征 <div class='azl-shipcard'> && <a> && get('href')")
        return ship_names, ship_links
    
    except Exception as e:
        print(f"x 提取舰船链接失败: {e}")
        return [], []

# %% [markdown]
# ---
# ### 【2】然后实现从某Ship的Gallery得到所有Skin的wiki下载链接
# - 注：提取full_url与image_name时可能会有重复项（且两者会同时与前面提取的元素重复），一个折中的办法是消除重复项，如下函数所示

# %%
# # 旧版本，无禁用词，对Dafault&Censored嵌套无法处理
# def get_image_links(url, base_name=None):  # todo
#     # 确定基础名称
#     if base_name is None:
#         parsed_url = urlparse(url)
#         path_segments = [p for p in parsed_url.path.split('/') if p]
#         base_name = path_segments[-2] if len(path_segments) >= 2 else 'Unknown'
    
#     # 发送HTTP请求
#     response = requests.get(url)
#     response.raise_for_status()
    
#     # 解析HTML内容
#     soup = BeautifulSoup(response.content, 'html.parser')
    
#     # 初始化结果列表
#     url_list = []
#     name_list = []
    
#     # 用于提取根名的正则表达式
#     pattern = re.compile(r'^tabber-tab-(.+?)-\d+$')
    
#     # 查找所有article标签
#     for article in soup.find_all('article', class_='tabber__panel'):
#         # 提取aria-labelledby属性
#         aria_label = article.get('aria-labelledby', '')
        
#         # 使用正则匹配根名
#         match = pattern.match(aria_label)
#         if not match:
#             continue
#         root_name = match.group(1)
        
#         # 处理两种类型的div
#         for div_type in ['shipskin-chibi', 'shipskin-image']:
#             div = article.find('div', class_=div_type)
#             if not div:
#                 continue
                
#             # 提取链接
#             link = div.find('a')
#             if not link or 'href' not in link.attrs:
#                 continue
                
#             # 构建完整URL
#             full_url = urljoin(url, link['href'])
            
#             # 构建图片名称
#             suffix = '_Chibi' if div_type == 'shipskin-chibi' else ''
#             image_name = f"{base_name}_{root_name}{suffix}"
            
#             # 添加到结果列表
#             name_list.append(image_name)
#             url_list.append(full_url)
    
#     return name_list, url_list


def get_image_links(url, base_name=None):
    # 获取基础名称
    if base_name is None:
        parsed = urlparse(url)
        path_segments = [p for p in parsed.path.split('/') if p]
        base_name = path_segments[-2] if len(path_segments) >= 2 else 'Unknown'
    
    # 获取并解析网页
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    
    image_urls = []
    image_names = []
    last_valid_root = None  # 用于处理Default逻辑
    
    # 遍历所有article标签
    for article in soup.find_all('article', class_='tabber__panel'):
        aria_label = article.get('aria-labelledby', '')
        
        # 跳过包含禁用词的标签
        if any(banned in aria_label for banned in ['Without_BG', 'Censored', 'EN']):
            continue
            
        # 解析aria-labelledby属性
        parts = aria_label.split('-')
        if len(parts) < 4 or not parts[-1].isdigit():
            continue  # 不符合格式要求
            
        root_part = '-'.join(parts[2:-1])  # 提取子图名称部分
        k_value = parts[-1]  # 提取k值
        
        # 处理HTML实体转义（如&#039;转'）
        root_part = BeautifulSoup(root_part, 'html.parser').get_text()
        
        # 处理Default逻辑
        if root_part == "Default":
            if k_value == "0":
                current_root = "Default"
                last_valid_root = current_root  # 记录但不强制使用
            else:
                current_root = last_valid_root or "Default"  # 优先使用上次有效名称
        else:
            current_root = root_part
            last_valid_root = current_root  # 更新有效名称
        
        # 处理两种图片容器
        for div_class in ['shipskin-chibi', 'shipskin-image']:
            container = article.find('div', class_=div_class)
            if not container:
                continue
                
            # 提取图片链接
            link = container.find('a', href=True)
            if not link:
                continue
                
            # 构建完整URL
            full_url = urljoin(url, link['href'])
            
            # 构建图片名称
            suffix = '_Chibi' if div_class == 'shipskin-chibi' else ''
            image_name = f"{base_name}_{current_root}{suffix}"
            
            # 清理特殊字符（保留字母数字、下划线、连字符、问号）
            image_name = re.sub(r'[^\w\-?]', '_', image_name)  # 替换非法字符
            image_name = re.sub(r'_+', '_', image_name)        # 合并连续下划线

            if (full_url not in image_urls) and (image_name not in image_names):  # 两者全不相同时满足
                image_names.append(image_name)
                image_urls.append(full_url)
    
    return image_names, image_urls


# 测试函数功能：
gallery_url = "https://azurlane.koumakan.jp/wiki/Helena/Gallery"  # Helena: 6 x 2
gallery_url = "https://azurlane.koumakan.jp/wiki/Belfast/Gallery"  # Belfast: 9 x 2
links, names = get_image_links(gallery_url)
print(f"找到 {len(links)} 个子图， {len(names)} 个名称\n")

for name, link in zip(names, links):
    print(name, link)
# Out:
# 找到 18 个子图， 18 个名称
#
# https://azurlane.koumakan.jp/wiki/File:BelfastChibi.png Belfast_Default_Chibi
# https://azurlane.koumakan.jp/wiki/File:Belfast.png Belfast_Default
# https://azurlane.koumakan.jp/wiki/File:BelfastWeddingChibi.png Belfast_Wedding_Chibi
# https://azurlane.koumakan.jp/wiki/File:BelfastWedding.png Belfast_Wedding
# https://azurlane.koumakan.jp/wiki/File:BelfastSpringChibi.png Belfast_Iridescent_Rosa_Chibi
# https://azurlane.koumakan.jp/wiki/File:BelfastSpring.png Belfast_Iridescent_Rosa
# https://azurlane.koumakan.jp/wiki/File:BelfastBlurayChibi.png Belfast_Serene_Steel_Chibi
# https://azurlane.koumakan.jp/wiki/File:BelfastBluray.png Belfast_Serene_Steel
# https://azurlane.koumakan.jp/wiki/File:BelfastPartyChibi.png Belfast_The_Noble_Attendant_Chibi
# https://azurlane.koumakan.jp/wiki/File:BelfastParty.png Belfast_The_Noble_Attendant
# https://azurlane.koumakan.jp/wiki/File:BelfastCasualChibi.png Belfast_Shopping_with_the_Head_Maid_Chibi
# https://azurlane.koumakan.jp/wiki/File:BelfastCasual.png Belfast_Shopping_with_the_Head_Maid
# https://azurlane.koumakan.jp/wiki/File:BelfastPizzaChibi.png Belfast_Piping-Hot_Perfection_Chibi
# https://azurlane.koumakan.jp/wiki/File:BelfastPizza.png Belfast_Piping-Hot_Perfection
# https://azurlane.koumakan.jp/wiki/File:BelfastNew_YearChibi.png Belfast_Folded_Fascination_Chibi
# https://azurlane.koumakan.jp/wiki/File:BelfastNew_Year.png Belfast_Folded_Fascination
# https://azurlane.koumakan.jp/wiki/File:BelfastTheme_ParkChibi.png Belfast_Blissful_Service_Chibi
# https://azurlane.koumakan.jp/wiki/File:BelfastTheme_Park.png Belfast_Blissful_Service

# %% [markdown]
# ---
# ### 【3】最后需要写一个函数实现从wiki上下载原图

# %%
# # 旧版本，下载时可能会报错：Connection broken: IncompleteRead
# def download_wiki_image_fullsize(file_page_url, save_path):  # todo
#     """
#     下载维基文件页面的原始尺寸图片（兼容最新BeautifulSoup版本）
    
#     参数:
#         file_page_url: 文件页面URL 
#         save_path: 图片保存路径
#     """
#     try:
#         # 1. 获取文件页面
#         response = requests.get(file_page_url, headers=headers)
#         response.raise_for_status()
#         soup = BeautifulSoup(response.text, 'html.parser')
        
#         # 2. 查找原始文件链接（新版写法）
#         full_res_link = None
#         for a_tag in soup.find_all("a"):
#             # 中文维基"原始文件"或英文维基"Original file"
#             if a_tag.string == "原始文件" or a_tag.string == "Original file":
#                 full_res_link = a_tag
#                 break
        
#         if not full_res_link:
#             raise ValueError("找不到原始文件链接")
        
#         # 3. 获取原始图片URL
#         original_img_url = urljoin(file_page_url, full_res_link["href"])
        
#         # 4. 下载并保存
#         os.makedirs(os.path.dirname(save_path), exist_ok=True)
#         img_data = requests.get(original_img_url, headers=headers).content
        
#         with open(save_path, "wb") as f:
#             f.write(img_data)
        
#         print(f"✓ 原始尺寸图片已保存到: {save_path}")
#         return True
    
#     except Exception as e:
#         print(f"× 下载失败: {str(e)}")
#         return False


def download_wiki_image_fullsize(file_page_url, save_path, max_retries=3):
    """
    下载维基文件页面的原始尺寸图片（兼容最新BeautifulSoup版本）
    
    参数:
        file_page_url: 文件页面URL 
        save_path: 图片保存路径
        max_retries: 最大重试次数 (默认3次)
    """
    retry_count = 0
    
    while retry_count < max_retries:
        try:
            # 1. 获取文件页面
            response = requests.get(file_page_url, headers=headers, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # 2. 查找原始文件链接（新版写法）
            full_res_link = None
            for a_tag in soup.find_all("a"):
                # 中文维基"原始文件"或英文维基"Original file"
                if a_tag.string and (a_tag.string.strip() == "原始文件" or a_tag.string.strip() == "Original file"):
                    full_res_link = a_tag
                    break
            
            if not full_res_link:
                print(f"ERROR: 找不到原始文件链接: {file_page_url}")
                break
            
            # 3. 获取原始图片URL
            original_img_url = urljoin(file_page_url, full_res_link["href"])
            
            # 4. 下载并保存
            os.makedirs(os.path.dirname(save_path), exist_ok=True)
            
            # 使用流式下载大文件
            with requests.get(original_img_url, headers=headers, stream=True, timeout=30) as img_response:
                img_response.raise_for_status()
                
                # 检查内容长度
                total_size = int(img_response.headers.get('content-length', 0))
                downloaded_size = 0
                
                with open(save_path, "wb") as f:
                    for chunk in img_response.iter_content(chunk_size=8192):
                        if chunk:  # 过滤掉保持连接的新块
                            f.write(chunk)
                            downloaded_size += len(chunk)
                
                # 验证下载完整性
                if total_size > 0 and downloaded_size != total_size:
                    raise IOError(f"WARNING: 下载不完整 (预期: {total_size}, 实际: {downloaded_size} 字节)")
            
            print(f"✓ 原始尺寸图片已保存到: {save_path}")
            return True
            
        except requests.exceptions.RequestException as e:
            retry_count += 1
            print(f"× 下载失败 (尝试 {retry_count}/{max_retries}): {str(e)}")
            if retry_count < max_retries:
                time.sleep(0.1 * 2 ** retry_count)  # 指数退避
            else:
                print(f"× 达到最大重试次数，放弃下载: {file_page_url}")
                return False
                
        except Exception as e:
            print(f"× 发生错误: {str(e)}")
            return False
            

# 使用示例
download_wiki_image_fullsize(
    "https://azurlane.koumakan.jp/wiki/File:Specialized_Bulin_Custom_MKIII.png",
    save_folder + "/test_3/Bulin_MKIII.png"
)
download_wiki_image_fullsize(
    "https://azurlane.koumakan.jp/wiki/File:HelenaPartyChibi.png",
    save_folder + "/test_3/HelenaPartyChibi.png"
)
# Out:
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/test_3/Bulin_MKIII.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HelenaPartyChibi.png

# %% [markdown]
# ---
# ### 【4】函数已经定义完成，开始准备下载：
#
# #### 【4.1】get_ship_links函数得到所有Ship的Gallery路径

# %%
ship_names, ship_links = get_ship_links()
print(f"√ 找到 {len(ship_names)} 个Ship链接")
# print(ship_links)

# 输出前几个提取的Ship Gallery URL看看效果~
for i in range(10):
    print(f"Ship: {ship_names[i]}: {ship_links[i]}")
# Out:
# 共有873个符合特征 <div class='azl-shipcard'>
# 共有873个符合特征 <div class='azl-shipcard'> && <a>
# 共有873个符合特征 <div class='azl-shipcard'> && <a> && get('href')
# ✅ 找到 873 个Ship链接
# 🚢 Universal Bulin: https://azurlane.koumakan.jp/wiki/Universal_Bulin/Gallery
# 🚢 Prototype Bulin MKII: https://azurlane.koumakan.jp/wiki/Prototype_Bulin_MKII/Gallery
# 🚢 Specialized Bulin Custom MKIII: https://azurlane.koumakan.jp/wiki/Specialized_Bulin_Custom_MKIII/Gallery
# 🚢 Dewey: https://azurlane.koumakan.jp/wiki/Dewey/Gallery
# 🚢 Cassin: https://azurlane.koumakan.jp/wiki/Cassin/Gallery
# 🚢 Downes: https://azurlane.koumakan.jp/wiki/Downes/Gallery
# 🚢 Gridley: https://azurlane.koumakan.jp/wiki/Gridley/Gallery
# 🚢 Craven: https://azurlane.koumakan.jp/wiki/Craven/Gallery
# 🚢 McCall: https://azurlane.koumakan.jp/wiki/McCall/Gallery
# 🚢 Maury: https://azurlane.koumakan.jp/wiki/Maury/Gallery

# %% [markdown]
# #### 【4.2】get_image_links函数得到Ship的所有Skin的wiki下载路径
#
# - 包括shipskin-chibi和shipskin-image
# - 不含Without_BG，Censored和EN

# %%
image_info_dict = dict()

# 再提取前几个Ship的所有Skin的wiki URL看看效果~
for i in range(5):
    image_names, image_urls = get_image_links(url=ship_links[i])
    image_info_dict[ship_names[i]] = list(zip(image_names, image_urls))

import yaml
print(yaml.dump(image_info_dict, allow_unicode=True, default_flow_style=False))
# Out:
# Cassin:
# - !!python/tuple
#   - Cassin_Default_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:CassinChibi.png
# - !!python/tuple
#   - Cassin_Default
#   - https://azurlane.koumakan.jp/wiki/File:Cassin.png
# - !!python/tuple
#   - Cassin_Retrofit_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:CassinKaiChibi.png
# - !!python/tuple
#   - Cassin_Retrofit
#   - https://azurlane.koumakan.jp/wiki/File:CassinKai.png
# - !!python/tuple
#   - Cassin_Shopping_Carte_Blanche_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:CassinSchoolChibi.png
# - !!python/tuple
#   - Cassin_Shopping_Carte_Blanche
#   - https://azurlane.koumakan.jp/wiki/File:CassinSchool.png
# Dewey:
# - !!python/tuple
#   - Dewey_Default_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:DeweyChibi.png
# - !!python/tuple
#   - Dewey_Default
#   - https://azurlane.koumakan.jp/wiki/File:Dewey.png
# - !!python/tuple
#   - Dewey_Summer_Longing_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:DeweySummerChibi.png
# - !!python/tuple
#   - Dewey_Summer_Longing
#   - https://azurlane.koumakan.jp/wiki/File:DeweySummer.png
# - !!python/tuple
#   - Dewey_A_Christmas_Thank-You_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:DeweyChristmasChibi.png
# - !!python/tuple
#   - Dewey_A_Christmas_Thank-You
#   - https://azurlane.koumakan.jp/wiki/File:DeweyChristmas.png
# Prototype Bulin MKII:
# - !!python/tuple
#   - Prototype_Bulin_MKII_Default_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:Prototype_Bulin_MKIIChibi.png
# - !!python/tuple
#   - Prototype_Bulin_MKII_Default
#   - https://azurlane.koumakan.jp/wiki/File:Prototype_Bulin_MKII.png
# - !!python/tuple
#   - Prototype_Bulin_MKII_Prototype_Advanced_Weaponry_Prop_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:Prototype_Bulin_MKIIEventChibi.png
# - !!python/tuple
#   - Prototype_Bulin_MKII_Prototype_Advanced_Weaponry_Prop_
#   - https://azurlane.koumakan.jp/wiki/File:Prototype_Bulin_MKIIEvent.png
# Specialized Bulin Custom MKIII:
# - !!python/tuple
#   - Specialized_Bulin_Custom_MKIII_Default_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:Specialized_Bulin_Custom_MKIIIChibi.png
# - !!python/tuple
#   - Specialized_Bulin_Custom_MKIII_Default
#   - https://azurlane.koumakan.jp/wiki/File:Specialized_Bulin_Custom_MKIII.png
# Universal Bulin:
# - !!python/tuple
#   - Universal_Bulin_Default_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:Universal_BulinChibi.png
# - !!python/tuple
#   - Universal_Bulin_Default
#   - https://azurlane.koumakan.jp/wiki/File:Universal_Bulin.png
# - !!python/tuple
#   - Universal_Bulin_Universal_Enhanced_Rigging_Experimental_α_Chibi
#   - https://azurlane.koumakan.jp/wiki/File:Universal_BulinEventChibi.png
# - !!python/tuple
#   - Universal_Bulin_Universal_Enhanced_Rigging_Experimental_α
#   - https://azurlane.koumakan.jp/wiki/File:Universal_BulinEvent.png

# %% [markdown]
# #### 【4.3】再加上download_wiki_image_fullsize下载函数就可以下载啦~
# - 这里就不再尝试了

# %%
# idx = 0
# idx_max = 10

# for key in image_info_dict.keys():
#     idx += 1
#     dl_ship_dir = save_folder + f"test_4/{key}"
    
#     for skin_tuple in image_info_dict[key]:
#         skin_name, skin_url = skin_tuple
#         download_wiki_image_fullsize(file_page_url=skin_url, save_path=dl_ship_dir + '/' + skin_name)
    
#     if idx >= idx_max:
#         break

# %% [markdown]
# ---
# ### 【5】最后，借助两个大循环，与前面得到的ship_links和ship_names，完整版的代码如下

# %%
fig_folder = save_folder + "/figs"

ship_num = len(ship_links)

image_info_dict = dict()

for i in range(ship_num):
    image_names, image_urls = get_image_links(url=ship_links[i])
    image_info_dict[ship_names[i]] = list(zip(image_names, image_urls))

for key in image_info_dict.keys():
    dl_ship_dir = fig_folder + f"/{key}"
    
    for skin_tuple in image_info_dict[key]:
        skin_name, skin_url = skin_tuple
        download_wiki_image_fullsize(file_page_url=skin_url, save_path=dl_ship_dir + '/' + skin_name + '.png')

    # print(f"Complete downloading images for ship: {image_info_dict[key]}")
# Out:
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Universal_BulinChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Universal Bulin/Universal_Bulin_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Universal_BulinEventChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Universal Bulin/Universal_Bulin_Universal_Enhanced_Rigging_Experimental_α.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Prototype_Bulin_MKIIChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Prototype Bulin MKII/Prototype_Bulin_MKII_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Prototype_Bulin_MKIIEventChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Prototype Bulin MKII/Prototype_Bulin_MKII_Prototype_Advanced_Weaponry_Prop_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Specialized_Bulin_Custom_MKIIIChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Specialized Bulin Custom MKIII/Specialized_Bulin_Custom_MKIII_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DeweyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Dewey/Dewey_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DeweySummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Dewey/Dewey_Summer_Longing.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DeweyChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Dewey/Dewey_A_Christmas_Thank-You.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CassinChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cassin/Cassin_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CassinKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cassin/Cassin_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CassinSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cassin/Cassin_Shopping_Carte_Blanche.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DownesChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Downes/Downes_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DownesKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Downes/Downes_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DownesSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Downes/Downes_Part-Time_Bomber.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GridleyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Gridley/Gridley_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GridleyChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Gridley/Gridley_Christmas_Photoshoot.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CravenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Craven/Craven_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CravenSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Craven/Craven_Cheerleader_On_The_Playground.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:McCallChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/McCall/McCall_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MauryChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Maury/Maury_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:FletcherChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Fletcher/Fletcher_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Charles_AusburneChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Charles Ausburne/Charles_Ausburne_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Charles_AusburneKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Charles Ausburne/Charles_Ausburne_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ThatcherChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Thatcher/Thatcher_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AulickChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Aulick/Aulick_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:FooteChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Foote/Foote_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SpenceChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Spence/Spence_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BensonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Benson/Benson_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BensonHalloweenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Benson/Benson_Cutie_Pumpkin_Pie.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Retrofit.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Original_Art.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyBilibiliChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Bili_Girl_33.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Snow_Rabbit_and_Candy_Apple.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeySpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_White_Rabbit_Welcomes_the_Spring.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyCoCoChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Bunny_Clerk?.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyBlurayChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Picnic_Adventure?.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyIdolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Bunny_Idol_Unmotivated.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyBluray2Chibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Sleep_to_Clean_Another_Day.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyKFCChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Sleepy_Teriyaki_Twister.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyRPGChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Sleepageddon.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LaffeyPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Laffey/Laffey_Lazy_Days.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SimsChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sims/Sims_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SimsKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sims/Sims_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HammannChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hammann/Hammann_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HammannKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hammann/Hammann_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HammannSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hammann/Hammann_Rebellious_Summer.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HammannPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hammann/Hammann_Prideful_Fairy_of_the_Ballroom.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HammannIdolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hammann/Hammann_Hammanyan_Pawnch_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HammannChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hammann/Hammann_Holy_Night_Surprise_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HammannRaceQueenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hammann/Hammann_Blushing_Fellow.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_Holy_Night_s_Embrace.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_The_Inquisitive_Recluse.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_New_Year_s_Outing.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeIdolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_Kitty_Idol.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeFestivalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_Moon_Festival_Spacewalk.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EldridgeSchool2Chibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Eldridge/Eldridge_After-School_Good_Girl.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:OmahaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Omaha/Omaha_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:RaleighChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Raleigh/Raleigh_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BrooklynChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Brooklyn/Brooklyn_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:PhoenixChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Phoenix/Phoenix_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HelenaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Helena/Helena_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HelenaKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Helena/Helena_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HelenaWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Helena/Helena_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HelenaNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Helena/Helena_New_Year_s_Bluebird.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HelenaPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Helena/Helena_May_I_Have_this_Dance?.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HelenaSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Helena/Helena_Shimmering_Triangle_Wave.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AtlantaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Atlanta/Atlanta_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JuneauChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Juneau/Juneau_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JuneauKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Juneau/Juneau_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JuneauPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Juneau/Juneau_In_the_Swan_Garden.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:San_DiegoChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/San Diego/San_Diego_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:San_DiegoKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/San Diego/San_Diego_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:San_DiegoWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/San Diego/San_Diego_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:San_DiegoChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/San Diego/San_Diego_Sandy_Claus.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandHalloweenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_Reaper_Fever.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_Gentry_Knight.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandRoadtripChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_Road_Trip_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_New_Year_s_Challenge_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandTravelChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_Southbound_Journey.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandParty2Chibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_Golden_Conductor.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ClevelandBunnyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cleveland/Cleveland_Knight_of_the_Pop-Up_Shop.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ColumbiaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Columbia/Columbia_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ColumbiaSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Columbia/Columbia_After-School_Odette.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ColumbiaTravelChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Columbia/Columbia_Across_the_Vast_Prairies.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:PensacolaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Pensacola/Pensacola_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Salt_Lake_CityChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Salt Lake City/Salt_Lake_City_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:NorthamptonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Northampton/Northampton_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ChicagoChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Chicago/Chicago_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HoustonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Houston/Houston_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:PortlandChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Portland/Portland_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:PortlandKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Portland/Portland_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:PortlandSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Portland/Portland_At_School_With_Indy_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IndianapolisChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Indianapolis/Indianapolis_Default.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Indianapolis/Indianapolis_Original_Art.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IndianapolisSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Indianapolis/Indianapolis_At_School_With_My_Sister_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IndianapolisPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Indianapolis/Indianapolis_The_Light_of_Circle_City.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AstoriaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Astoria/Astoria_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AstoriaSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Astoria/Astoria_Pure_Gurl?_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AstoriaBunnyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Astoria/Astoria_Black_Bunny_Carnival.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:QuincyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Quincy/Quincy_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:QuincySummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Quincy/Quincy_Sizzling_Summer_Brisk_Breeze.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VincennesChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vincennes/Vincennes_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VincennesSleepyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vincennes/Vincennes_Sweet_Dreams.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VincennesSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vincennes/Vincennes_Leisurely_ABC_s.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:WichitaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Wichita/Wichita_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:WichitaPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Wichita/Wichita_The_General_s_Banquet.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:WichitaHalloweenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Wichita/Wichita_Domineering_Witchita.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BaltimoreChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Baltimore/Baltimore_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BaltimoreSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Baltimore/Baltimore_After-School_Ace.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BaltimoreSportChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Baltimore/Baltimore_Black_Ace.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BaltimorePartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Baltimore/Baltimore_Evening_Breeze_Minuet.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BaltimoreNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Baltimore/Baltimore_Ace_s_Travel_Journal.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BaltimoreRaceQueenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Baltimore/Baltimore_Finish_Line_Flagbearer.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:NevadaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Nevada/Nevada_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:NevadaKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Nevada/Nevada_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:NevadaPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Nevada/Nevada_A_Magnificent_Banquet.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:OklahomaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Oklahoma/Oklahoma_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:OklahomaKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Oklahoma/Oklahoma_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:OklahomaHalloweenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Oklahoma/Oklahoma_Piratey_Transformation_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:PennsylvaniaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Pennsylvania/Pennsylvania_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:PennsylvaniaSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Pennsylvania/Pennsylvania_The_Keystone_General.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ArizonaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Arizona/Arizona_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ArizonaSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Arizona/Arizona_Enchantress_from_Afar.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:TennesseeChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Tennessee/Tennessee_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CaliforniaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/California/California_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ColoradoChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Colorado/Colorado_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ColoradoOriginalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Colorado/Colorado_Original_Art.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ColoradoKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Colorado/Colorado_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ColoradoTravelChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Colorado/Colorado_Traveling_Melody.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MarylandChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Maryland/Maryland_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MarylandOriginalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Maryland/Maryland_Original_Art.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MarylandKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Maryland/Maryland_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:West_VirginiaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/West Virginia/West_Virginia_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:West_VirginiaOriginalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/West Virginia/West_Virginia_Original_Art.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:West_VirginiaKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/West Virginia/West_Virginia_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:West_VirginiaSportChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/West Virginia/West_Virginia_Scenic_Rhapsody.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:North_CarolinaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/North Carolina/North_Carolina_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:North_CarolinaBunnyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/North Carolina/North_Carolina_The_Heart_s_Desire.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:WashingtonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Washington/Washington_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:WashingtonSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Washington/Washington_Jubilant_Smile.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:WashingtonHospitalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Washington/Washington_Making_the_Rounds.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:South_DakotaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/South Dakota/South_Dakota_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:South_DakotaPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/South Dakota/South_Dakota_Solo_Concert.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IndianaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Indiana/Indiana_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IndianaWild_WestChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Indiana/Indiana_High_Noon_Arrest.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:New_JerseyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/New Jersey/New_Jersey_Default.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/New Jersey/New_Jersey_WithoutRig.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:New_JerseyWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/New Jersey/New_Jersey_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:New_JerseyBunnyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/New Jersey/New_Jersey_Exhilarating_Steps_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:New_JerseySummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/New Jersey/New_Jersey_Midsummer_Leisure.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:New_JerseySpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/New Jersey/New_Jersey_Dancing_in_the_Moonlight.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Long_IslandChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Long Island/Long_Island_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Long_IslandKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Long Island/Long_Island_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Long_IslandBilibiliChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Long Island/Long_Island_Long_Island_-_Indoor_Slacker.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Long_IslandHalloweenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Long Island/Long_Island_Long_Island_s_Spooky_Stream.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Long_IslandWorkChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Long Island/Long_Island_Ghostly_Receptionist.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BogueChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Bogue/Bogue_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BogueKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Bogue/Bogue_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LangleyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Langley/Langley_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LangleyKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Langley/Langley_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LexingtonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Lexington/Lexington_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LexingtonSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Lexington/Lexington_The_Beauty_of_Spring.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Seven_Seas_of_Rest.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaHanbokChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Hibiscus-scented_Idol.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaKizunaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Virtual_Idol.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaEventChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Superstar_of_the_Blue_Seas.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Silent_Night_Songstress.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Spring_s_Opening_Act_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaCasualChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_The_Sweetest_Picnic_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaFoodChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Cup_Ramen_Ambassador?.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_CN.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SaratogaPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saratoga/Saratoga_Morning_Sun_Over_Azure_Skies.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:RangerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ranger/Ranger_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:RangerKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ranger/Ranger_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:YorktownChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Yorktown/Yorktown_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:YorktownWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Yorktown/Yorktown_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:YorktownPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Yorktown/Yorktown_Evening_I_Can_t_Remember.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:YorktownTravelChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Yorktown/Yorktown_Saintly_Wings.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Reindeer_Master.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Blooming_Peony.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseRoadtripChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Anniversary_Ride.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseBlurayChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Soaring_Wings_of_Freedom.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterprisePartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Heroic_Finery.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseRaceQueenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Wind_Catcher.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseTravelChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Bon_Voyage.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EnterpriseSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Enterprise/Enterprise_Diving_Under_Blue_Skies.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HornetChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hornet/Hornet_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HornetPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hornet/Hornet_Bubbly_Anniversary_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HornetPizzaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hornet/Hornet_Freshly-Baked_Bonding_.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hornet/Hornet_JP.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HornetSportChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hornet/Hornet_Cheering_Justice_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:WaspChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Wasp/Wasp_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VestalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vestal/Vestal_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VestalSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vestal/Vestal_Revigorating_Hestia.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AmazonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Amazon/Amazon_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AmazonKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Amazon/Amazon_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AmazonPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Amazon/Amazon_Little_Orchestra.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AcastaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Acasta/Acasta_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AcastaKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Acasta/Acasta_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AcastaSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Acasta/Acasta_Fashionable_Outing.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AcastaMiscChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Acasta/Acasta_Lights_of_the_Lantern_Festival.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AcastaBunnyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Acasta/Acasta_Monochromatic_Marvel.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ArdentChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ardent/Ardent_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ArdentKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ardent/Ardent_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ArdentSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ardent/Ardent_Ardent_Valentine.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ArdentBunnyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ardent/Ardent_Master_Ardent?.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BeagleChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Beagle/Beagle_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BulldogChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Bulldog/Bulldog_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CometChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Comet/Comet_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CometKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Comet/Comet_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CrescentChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Crescent/Crescent_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CrescentKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Crescent/Crescent_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CygnetChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cygnet/Cygnet_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CygnetKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cygnet/Cygnet_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CygnetSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cygnet/Cygnet_Sea_Star_on_Shore.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CygnetChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cygnet/Cygnet_Holy_Night_s_Hymn.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CygnetNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cygnet/Cygnet_Winter_Date.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CygnetMaidChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cygnet/Cygnet_An_Offer_To_Be_Maid.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CygnetSportChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cygnet/Cygnet_Royal_Fanfare.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:FoxhoundChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Foxhound/Foxhound_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:FoxhoundKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Foxhound/Foxhound_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:FortuneChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Fortune/Fortune_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:FortuneKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Fortune/Fortune_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:FortunePartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Fortune/Fortune_Seraphic_Sunshine.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GrenvilleChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Grenville/Grenville_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GlowwormChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Glowworm/Glowworm_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GlowwormSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Glowworm/Glowworm_Jokey_Adjudicator.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HardyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hardy/Hardy_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:HunterChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hunter/Hunter_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinBilibiliChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Bili_Girl_22.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Beach_Picnic_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinCoCoChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Let_s_Become_Waitresses_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Slow_Ahead_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinBlurayChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Operation_Pillow_Fight_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinIdolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_Energetic_Idol_120_Motivation_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinRPGChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_A_Legend_is_Born?_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JavelinPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Javelin/Javelin_A_Different_Dance.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JunoChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Juno/Juno_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:JunoFestivalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Juno/Juno_Fairly_Flavourful_Festival.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VampireChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vampire/Vampire_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VampireWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vampire/Vampire_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VampireSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vampire/Vampire_The_Breath_of_Spring.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VampireNurseChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vampire/Vampire_Little_Devil_in_White.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VampireFestivalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vampire/Vampire_Night_Princess_s_Regalia.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VampireIdolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vampire/Vampire_Night_Princess_Idol.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:VampireChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vampire/Vampire_Night_Princess_s_Festive_Feast.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LeanderChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Leander/Leander_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LeanderKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Leander/Leander_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AchillesChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Achilles/Achilles_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AchillesKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Achilles/Achilles_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AjaxChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ajax/Ajax_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AjaxKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ajax/Ajax_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AjaxPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ajax/Ajax_Party_Queen.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AjaxSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ajax/Ajax_Valentine_s_Reward?.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DidoChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Dido/Dido_Dido.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DidoPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Dido/Dido_Anxious_Bisque_Doll.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Dido_%C2%B5Chibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Dido/Dido_Dido_µ.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SouthamptonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Southampton/Southampton_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SouthamptonWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Southampton/Southampton_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SouthamptonNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Southampton/Southampton_New_Year_s_Little_Knight.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SouthamptonMaidChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Southampton/Southampton_Afternoon_Impromptu.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SheffieldChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sheffield/Sheffield_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SheffieldMiscChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sheffield/Sheffield_Cloak_and_Dagger.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SheffieldFestivalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sheffield/Sheffield_A_Moment_s_Respite.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SheffieldPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sheffield/Sheffield_Black_Crow_s_Finery.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SheffieldVampireChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sheffield/Sheffield_Bulletborne.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SheffieldTheme_ParkChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sheffield/Sheffield_Occult_Clash.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ManchesterChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Manchester/Manchester_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ManchesterHalloweenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Manchester/Manchester_Midnight_Devil_in_White.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ManchesterSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Manchester/Manchester_A_Moment_in_the_Shade.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GloucesterChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Gloucester/Gloucester_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GloucesterSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Gloucester/Gloucester_Brilliance_in_Purple.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GloucesterTheme_ParkChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Gloucester/Gloucester_Violet_Enrapturement.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EdinburghChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Edinburgh/Edinburgh_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EdinburghSchoolChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Edinburgh/Edinburgh_The_Library_Fairy.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:EdinburghHalloweenChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Edinburgh/Edinburgh_Candy_Maid.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_Iridescent_Rosa.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastBlurayChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_Serene_Steel.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_The_Noble_Attendant.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastCasualChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_Shopping_with_the_Head_Maid.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastPizzaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_Piping-Hot_Perfection.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_Folded_Fascination.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:BelfastTheme_ParkChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Belfast/Belfast_Blissful_Service.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ArethusaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Arethusa/Arethusa_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GalateaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Galatea/Galatea_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AuroraChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Aurora/Aurora_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AuroraWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Aurora/Aurora_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AuroraSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Aurora/Aurora_The_Tale_of_Spring.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AuroraPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Aurora/Aurora_Dawn_s_Paean.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AuroraCollabChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Aurora/Aurora_Heritage_of_Yu_City.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LondonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/London/London_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LondonKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/London/London_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LondonWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/London/London_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:LondonWorkChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/London/London_The_Sterling_Secretary.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ShropshireChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Shropshire/Shropshire_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ShropshireKaiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Shropshire/Shropshire_Retrofit.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:KentChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Kent/Kent_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SuffolkChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Suffolk/Suffolk_Default.png
# ...
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Monarch/Monarch_White_Warrick.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MonarchSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Monarch/Monarch_Black_Gerard.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MonarchSpecial_ExerciseChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Monarch/Monarch_Detective_Arriving_on_the_Scene.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IbukiChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ibuki/Ibuki_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IbukiNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ibuki/Ibuki_Winter_Sylph_s_Reverie.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IbukiPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ibuki/Ibuki_Snow_on_the_Wind.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IbukiSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ibuki/Ibuki_Arrival_of_Spring.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IbukiCasualChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ibuki/Ibuki_Tranquil_Sunya.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IzumoChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Izumo/Izumo_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:IzumoNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Izumo/Izumo_Izumo_s_Thousand_Cherry_Trees.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:RoonChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Roon/Roon_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:RoonPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Roon/Roon_Dark_Red_Grin.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:RoonSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Roon/Roon_Viridescent_Lullaby.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Saint_LouisChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saint Louis/Saint_Louis_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Saint_LouisPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saint Louis/Saint_Louis_Holy_Knight_s_Resplendence.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Saint_LouisSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Saint Louis/Saint_Louis_Alluring_Administrator.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SeattleChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Seattle/Seattle_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SeattlePartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Seattle/Seattle_Gorgeous_Party.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SeattleChristmasChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Seattle/Seattle_Christmas_Party_Prep_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:SeattleSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Seattle/Seattle_Sunfish_Spell_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GeorgiaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Georgia/Georgia_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GeorgiaPartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Georgia/Georgia_South_Town_Pearl.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GeorgiaSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Georgia/Georgia_Lanier_Swan.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GeorgiaNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Georgia/Georgia_Exalted_Vibrance.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:KitakazeChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Kitakaze/Kitakaze_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:KitakazeFestivalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Kitakaze/Kitakaze_Celebration_Conquest_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:KitakazeTravelChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Kitakaze/Kitakaze_Night_of_Doves_and_Magic.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AzumaChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Azuma/Azuma_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AzumaWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Azuma/Azuma_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AzumaSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Azuma/Azuma_Soft_Voice_of_Spring.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GascogneChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Gascogne/Gascogne_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:GascogneSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Gascogne/Gascogne_Tropical_Environs_Acclimation_Service_Equipment.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CheshireChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cheshire/Cheshire_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CheshireSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cheshire/Cheshire_Summery_Date_.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CheshireSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cheshire/Cheshire_Cait_Sith_Crooner.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CheshirePartyChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cheshire/Cheshire_The_Cat_and_the_White_Steed.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:CheshireParty2Chibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Cheshire/Cheshire_The_Cat_in_the_Magic_Hat.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DrakeChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Drake/Drake_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:DrakeSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Drake/Drake_The_Golden_Hind_s_Respite.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MainzChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Mainz/Mainz_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MainzHot_SpringsChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Mainz/Mainz_The_Silkiest_Brew.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:MainzSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Mainz/Mainz_A_Blend_of_Serenity.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:OdinChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Odin/Odin_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:OdinNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Odin/Odin_Black_Strokes_upon_Blank_Snow.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ChampagneChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Champagne/Champagne_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ChampagneWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Champagne/Champagne_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:ChampagneNew_YearChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Champagne/Champagne_Lapis_Lazuli_s_First_Dream.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AnchorageChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Anchorage/Anchorage_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AnchorageWeddingChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Anchorage/Anchorage_Wedding.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AnchorageSummerChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Anchorage/Anchorage_Dolphins_and_Swim_Lessons.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:AnchorageSpringChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Anchorage/Anchorage_Moonlit_Boat_Ride.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:August_von_ParsevalChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/August von Parseval/August_von_Parseval_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:August_von_ParsevalMaidChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/August von Parseval/August_von_Parseval_The_Conquered_Unhulde.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:August_von_ParsevalHome_RelaxationChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/August von Parseval/August_von_Parseval_The_Unhulde_s_Midday_Respite.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Marco_PoloChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Marco Polo/Marco_Polo_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Marco_PoloMaidChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Marco Polo/Marco_Polo_The_Queen_of_Hearts.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Hiryuu_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hiryuu META/Hiryuu_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Ark_Royal_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Ark Royal META/Ark_Royal_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Helena_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Helena META/Helena_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Souryuu_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Souryuu META/Souryuu_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Fusou_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Fusou META/Fusou_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Hiyou_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hiyou META/Hiyou_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Gneisenau_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Gneisenau META/Gneisenau_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Junyou_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Junyou META/Junyou_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Scharnhorst_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Scharnhorst META/Scharnhorst_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Yamashiro_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Yamashiro META/Yamashiro_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Memphis_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Memphis META/Memphis_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Repulse_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Repulse META/Repulse_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Trento_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Trento META/Trento_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Renown_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Renown META/Renown_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Hunter_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hunter META/Hunter_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Fortune_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Fortune META/Fortune_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Arizona_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Arizona META/Arizona_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Sheffield_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Sheffield META/Sheffield_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Queen_Elizabeth_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Queen Elizabeth META/Queen_Elizabeth_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:La_Galissonni%C3%A8re_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/La Galissonnière META/La_Galissonni_C3_A8re_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:U-556_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/U-556 META/U-556_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Vestal_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vestal META/Vestal_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Alg%C3%A9rie_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Algérie META/Alg_C3_A9rie_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Hatakaze_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hatakaze META/Hatakaze_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Jintsuu_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Jintsuu META/Jintsuu_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Princeton_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Princeton META/Princeton_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Erebus_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Erebus META/Erebus_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Kirov_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Kirov META/Kirov_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Kimberly_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Kimberly META/Kimberly_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Pamiat%27_Merkuria_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Pamiat' Merkuria META/Pamiat_27_Merkuria_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Rodney_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Rodney META/Rodney_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Vampire_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Vampire META/Vampire_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:B%C3%A9arn_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Béarn META/B_C3_A9arn_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Foch_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Foch META/Foch_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Wichita_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Wichita META/Wichita_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Kasumi_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Kasumi META/Kasumi_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Nagato_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Nagato META/Nagato_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Hiei_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hiei META/Hiei_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Houshou_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Houshou META/Houshou_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Giulio_Cesare_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Giulio Cesare META/Giulio_Cesare_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Taihou_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Taihou META/Taihou_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Admiral_Hipper_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Admiral Hipper META/Admiral_Hipper_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Bolzano_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Bolzano META/Bolzano_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Andrea_Doria_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Andrea Doria META/Andrea_Doria_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Hornet_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Hornet META/Hornet_META_Default.png
# × 找不到原始文件链接: https://azurlane.koumakan.jp/wiki/File:Nevada_METAChibi.png
# ✓ 原始尺寸图片已保存到: /kaggle/working/20250328/figs/Nevada META/Nevada_META_Default.png
